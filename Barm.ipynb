# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib inline
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
student=['Ramesh', 'Shyam','Hari']
grade=[90,80,85]
ax.bar(student,grade)
ax.set_ylabel("SSS")
plt.show()
